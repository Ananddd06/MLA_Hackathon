# %%
import pandas as pd

# Load the datasets
train_df = pd.read_csv('/content/Train_set.csv')
test_df = pd.read_csv('/content/Test_set.csv')

# Display the first 5 rows
print("Train DataFrame head:")
display(train_df.head())
print("\nTest DataFrame head:")
display(test_df.head())

# Print the shape of the DataFrames
print("\nTrain DataFrame shape:", train_df.shape)
print("Test DataFrame shape:", test_df.shape)

# Display data types and non-null values
print("\nTrain DataFrame info:")
train_df.info()
print("\nTest DataFrame info:")
test_df.info()

# Check for duplicate rows
print("\nTrain DataFrame duplicate rows:", train_df.duplicated().sum())
print("Test DataFrame duplicate rows:", test_df.duplicated().sum())

# Calculate and display missing values
print("\nTrain DataFrame missing values:")
print(train_df.isnull().sum())
print("\nTest DataFrame missing values:")
print(test_df.isnull().sum())
# Out:
# Train DataFrame head:
#          ID  loan_amnt loan_term  interest_rate loan_grade loan_subgrade  \
# 0  72199369       9000   3 years           9.17          B            B2
# 1  14257956      18000   3 years          13.65          C            C1
# 2  66216451      16000   3 years           7.26          A            A4
# 3  46974169      25000   3 years          13.99          C            C4
# 4  46725961      17000   3 years           6.39          A            A2
#
#   job_experience home_ownership  annual_income income_verification_status  \
# 0       <5 Years            OWN        85000.0               Not Verified
# 1       <5 Years            OWN        64000.0                   Verified
# 2       <5 Years       MORTGAGE       150000.0            Source Verified
# 3            NaN       MORTGAGE        59800.0                   Verified
# 4      10+ years       MORTGAGE        72000.0            Source Verified
#
#    ... delinq_2yrs public_records  revolving_balance  total_acc  \
# 0  ...         0.0            0.0              39519       20.0
# 1  ...         0.0            1.0               9783       24.0
# 2  ...         2.0            0.0              13641       27.0
# 3  ...         0.0            0.0              35020       35.0
# 4  ...         0.0            0.0              23990       26.0
#
#    interest_receive  application_type  last_week_pay  total_current_balance  \
# 0             59.60        INDIVIDUAL            4.0                95493.0
# 1           3348.25        INDIVIDUAL           95.0               185433.0
# 2            276.69        INDIVIDUAL           13.0               180519.0
# 3           1106.72        INDIVIDUAL           17.0               183208.0
# 4            725.29        INDIVIDUAL           39.0                23990.0
#
#   total_revolving_limit  default
# 0               84100.0        0
# 1               13500.0        0
# 2               19300.0        0
# 3               55400.0        0
# 4               81300.0        0
#
# [5 rows x 23 columns]
# Test DataFrame head:
#          ID  loan_amnt loan_term  interest_rate loan_grade loan_subgrade  \
# 0   4855329      12000   3 years          15.31          C            C2
# 1  66862420      12000   3 years           7.26          A            A4
# 2   3637416      15000   3 years          14.33          C            C1
# 3  53682249      12000   3 years           9.99          B            B3
# 4  53937165      20150   3 years          11.53          B            B5
#
#   job_experience home_ownership  annual_income income_verification_status  \
# 0       <5 Years       MORTGAGE        73400.0               Not Verified
# 1      10+ years       MORTGAGE       105000.0               Not Verified
# 2     6-10 years       MORTGAGE        50000.0                   Verified
# 3     6-10 years           RENT        37000.0            Source Verified
# 4       <5 Years           RENT        75000.0            Source Verified
#
#    ... debt_to_income delinq_2yrs  public_records  revolving_balance  \
# 0  ...          14.62         0.0             0.0              22156
# 1  ...          11.38         0.0             0.0               7592
# 2  ...          28.15         0.0             1.0              17983
# 3  ...          34.32         0.0             0.0              12262
# 4  ...          26.74         1.0             0.0               8251
#
#    total_acc  interest_receive  application_type  last_week_pay  \
# 0       30.0           2290.24        INDIVIDUAL           87.0
# 1       14.0            202.68        INDIVIDUAL           13.0
# 2       19.0           1166.24        INDIVIDUAL           30.0
# 3       18.0            635.06        INDIVIDUAL           35.0
# 4       11.0           1232.84        INDIVIDUAL           31.0
#
#   total_current_balance  total_revolving_limit
# 0              128098.0                25800.0
# 1              269396.0                23600.0
# 2              220135.0                34100.0
# 3               39436.0                21700.0
# 4               52764.0                12000.0
#
# [5 rows x 22 columns]
# Train DataFrame shape: (93174, 23)
# Test DataFrame shape: (39933, 22)
#
# Train DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93174 entries, 0 to 93173
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          93174 non-null  int64
#  1   loan_amnt                   93174 non-null  int64
#  2   loan_term                   93174 non-null  object
#  3   interest_rate               93174 non-null  float64
#  4   loan_grade                  93174 non-null  object
#  5   loan_subgrade               93174 non-null  object
#  6   job_experience              88472 non-null  object
#  7   home_ownership              93174 non-null  object
#  8   annual_income               93173 non-null  float64
#  9   income_verification_status  93174 non-null  object
#  10  loan_purpose                93174 non-null  object
#  11  state_code                  93174 non-null  object
#  12  debt_to_income              93174 non-null  float64
#  13  delinq_2yrs                 93172 non-null  float64
#  14  public_records              93172 non-null  float64
#  15  revolving_balance           93174 non-null  int64
#  16  total_acc                   93172 non-null  float64
#  17  interest_receive            93174 non-null  float64
#  18  application_type            93174 non-null  object
#  19  last_week_pay               91250 non-null  float64
#  20  total_current_balance       85788 non-null  float64
#  21  total_revolving_limit       85788 non-null  float64
#  22  default                     93174 non-null  int64
# dtypes: float64(10), int64(4), object(9)
# memory usage: 16.3+ MB
#
# Test DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39933 entries, 0 to 39932
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          39933 non-null  int64
#  1   loan_amnt                   39933 non-null  int64
#  2   loan_term                   39933 non-null  object
#  3   interest_rate               39933 non-null  float64
#  4   loan_grade                  39933 non-null  object
#  5   loan_subgrade               39933 non-null  object
#  6   job_experience              37844 non-null  object
#  7   home_ownership              39933 non-null  object
#  8   annual_income               39933 non-null  float64
#  9   income_verification_status  39933 non-null  object
#  10  loan_purpose                39933 non-null  object
#  11  state_code                  39933 non-null  object
#  12  debt_to_income              39933 non-null  float64
#  13  delinq_2yrs                 39932 non-null  float64
#  14  public_records              39932 non-null  float64
#  15  revolving_balance           39933 non-null  int64
#  16  total_acc                   39932 non-null  float64
#  17  interest_receive            39933 non-null  float64
#  18  application_type            39933 non-null  object
#  19  last_week_pay               39127 non-null  float64
#  20  total_current_balance       36703 non-null  float64
#  21  total_revolving_limit       36703 non-null  float64
# dtypes: float64(10), int64(3), object(9)
# memory usage: 6.7+ MB
#
# Train DataFrame duplicate rows: 0
# Test DataFrame duplicate rows: 0
#
# Train DataFrame missing values:
# ID                               0
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                4702
# home_ownership                   0
# annual_income                    1
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      2
# public_records                   2
# revolving_balance                0
# total_acc                        2
# interest_receive                 0
# application_type                 0
# last_week_pay                 1924
# total_current_balance         7386
# total_revolving_limit         7386
# default                          0
# dtype: int64
#
# Test DataFrame missing values:
# ID                               0
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                2089
# home_ownership                   0
# annual_income                    0
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      1
# public_records                   1
# revolving_balance                0
# total_acc                        1
# interest_receive                 0
# application_type                 0
# last_week_pay                  806
# total_current_balance         3230
# total_revolving_limit         3230
# dtype: int64

# %% [markdown]
# ## Exploratory data analysis (eda)
#
# ### Subtask:
# Analyze categorical features, visualize missing values and outliers, examine the target variable distribution, and visualize correlations among numerical features. Handle skewness if necessary.

# %% [markdown]
# **Reasoning**:
# Identify categorical and numerical columns, analyze unique values and frequencies for categorical columns, and visualize missing values for both train and test datasets.

# %%
train_df['default'].value_counts()
# Out:
# default
# 0    71045
# 1    22129
# Name: count, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Identify categorical and numerical columns
categorical_cols_train = train_df.select_dtypes(include='object').columns
numerical_cols_train = train_df.select_dtypes(include=np.number).columns

categorical_cols_test = test_df.select_dtypes(include='object').columns
numerical_cols_test = test_df.select_dtypes(include=np.number).columns

print("Categorical columns in train data:", categorical_cols_train.tolist())
print("Numerical columns in train data:", numerical_cols_train.tolist())
print("\nCategorical columns in test data:", categorical_cols_test.tolist())
print("Numerical columns in test data:", numerical_cols_test.tolist())

# Analyze unique values and frequencies for categorical columns in train data
print("\nAnalysis of categorical columns in train data:")
for col in categorical_cols_train:
    print(f"\nColumn: {col}")
    print("Unique values:", train_df[col].unique())
    print("Value Counts:\n", train_df[col].value_counts())

# Analyze unique values and frequencies for categorical columns in test data
print("\nAnalysis of categorical columns in test data:")
for col in categorical_cols_test:
    print(f"\nColumn: {col}")
    print("Unique values:", test_df[col].unique())
    print("Value Counts:\n", test_df[col].value_counts())


# Visualize missing values
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.heatmap(train_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap (Train Data)')

plt.subplot(1, 2, 2)
sns.heatmap(test_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap (Test Data)')

plt.tight_layout()
plt.show()
# Out:
# Categorical columns in train data: ['loan_term', 'loan_grade', 'loan_subgrade', 'job_experience', 'home_ownership', 'income_verification_status', 'loan_purpose', 'state_code', 'application_type']
# Numerical columns in train data: ['ID', 'loan_amnt', 'interest_rate', 'annual_income', 'debt_to_income', 'delinq_2yrs', 'public_records', 'revolving_balance', 'total_acc', 'interest_receive', 'last_week_pay', 'total_current_balance', 'total_revolving_limit', 'default']
#
# Categorical columns in test data: ['loan_term', 'loan_grade', 'loan_subgrade', 'job_experience', 'home_ownership', 'income_verification_status', 'loan_purpose', 'state_code', 'application_type']
# Numerical columns in test data: ['ID', 'loan_amnt', 'interest_rate', 'annual_income', 'debt_to_income', 'delinq_2yrs', 'public_records', 'revolving_balance', 'total_acc', 'interest_receive', 'last_week_pay', 'total_current_balance', 'total_revolving_limit']
#
# Analysis of categorical columns in train data:
#
# Column: loan_term
# Unique values: ['3 years' '5 years']
# Value Counts:
#  loan_term
# 3 years    65211
# 5 years    27963
# Name: count, dtype: int64
#
# Column: loan_grade
# Unique values: ['B' 'C' 'A' 'E' 'D' 'F' 'G']
# Value Counts:
#  loan_grade
# B    26865
# C    25787
# A    15534
# D    14715
# E     7378
# F     2344
# G      551
# Name: count, dtype: int64
#
# Column: loan_subgrade
# Unique values: ['B2' 'C1' 'A4' 'C4' 'A2' 'C2' 'B4' 'A5' 'E2' 'B5' 'A3' 'C5' 'E5' 'B1'
#  'D5' 'D4' 'E3' 'B3' 'C3' 'D3' 'A1' 'F5' 'E1' 'E4' 'F3' 'D1' 'G3' 'F2'
#  'D2' 'F4' 'F1' 'G1' 'G5' 'G2' 'G4']
# Value Counts:
#  loan_subgrade
# B4    5879
# B3    5879
# C2    5479
# C1    5443
# C3    5270
# C4    5182
# B2    5169
# B5    5095
# B1    4843
# A5    4723
# C5    4413
# D1    3716
# A4    3631
# D2    3239
# D3    2759
# D4    2717
# A3    2450
# A1    2377
# A2    2353
# D5    2284
# E1    1924
# E2    1736
# E3    1513
# E4    1228
# E5     977
# F1     745
# F2     545
# F3     465
# F4     355
# F5     234
# G1     174
# G2     146
# G3     105
# G5      66
# G4      60
# Name: count, dtype: int64
#
# Column: job_experience
# Unique values: ['<5 Years' nan '10+ years' '6-10 years']
# Value Counts:
#  job_experience
# <5 Years      40610
# 10+ years     30362
# 6-10 years    17500
# Name: count, dtype: int64
#
# Column: home_ownership
# Unique values: ['OWN' 'MORTGAGE' 'RENT' 'NONE' 'OTHER']
# Value Counts:
#  home_ownership
# MORTGAGE    46445
# RENT        37449
# OWN          9254
# OTHER          18
# NONE            8
# Name: count, dtype: int64
#
# Column: income_verification_status
# Unique values: ['Not Verified' 'Verified' 'Source Verified']
# Value Counts:
#  income_verification_status
# Source Verified    34487
# Verified           30450
# Not Verified       28237
# Name: count, dtype: int64
#
# Column: loan_purpose
# Unique values: ['debt_consolidation' 'credit_card' 'other' 'home_improvement']
# Value Counts:
#  loan_purpose
# debt_consolidation    55241
# credit_card           21571
# other                 10971
# home_improvement       5391
# Name: count, dtype: int64
#
# Column: state_code
# Unique values: ['NC' 'SC' 'TX' 'MO' 'IL' 'NY' 'CT' 'CA' 'VA' 'GA' 'OR' 'NV' 'LA' 'RI'
#  'IN' 'AZ' 'OK' 'MN' 'WY' 'HI' 'MI' 'CO' 'MS' 'NJ' 'WA' 'UT' 'NM' 'KY'
#  'MA' 'FL' 'PA' 'WI' 'OH' 'DE' 'DC' 'WV' 'MD' 'TN' 'NE' 'AL' 'KS' 'SD'
#  'VT' 'MT' 'AK' 'AR' 'NH' 'ME' 'ND' 'ID']
# Value Counts:
#  state_code
# CA    13744
# NY     7782
# TX     7467
# FL     6360
# IL     3699
# NJ     3464
# PA     3321
# OH     3104
# GA     2998
# VA     2793
# NC     2669
# MI     2415
# MD     2279
# MA     2232
# AZ     2115
# WA     2038
# CO     1924
# MN     1638
# MO     1485
# IN     1420
# CT     1402
# TN     1365
# NV     1326
# WI     1206
# AL     1188
# LA     1112
# SC     1108
# OR     1102
# KY      933
# OK      851
# KS      800
# AR      694
# UT      658
# NM      507
# WV      460
# HI      451
# NH      447
# RI      412
# MS      389
# DC      271
# MT      253
# DE      246
# AK      231
# WY      212
# SD      198
# VT      174
# NE      126
# ME       59
# ND       45
# ID        1
# Name: count, dtype: int64
#
# Column: application_type
# Unique values: ['INDIVIDUAL' 'JOINT']
# Value Counts:
#  application_type
# INDIVIDUAL    93118
# JOINT            56
# Name: count, dtype: int64
#
# Analysis of categorical columns in test data:
#
# Column: loan_term
# Unique values: ['3 years' '5 years']
# Value Counts:
#  loan_term
# 3 years    28110
# 5 years    11823
# Name: count, dtype: int64
#
# Column: loan_grade
# Unique values: ['C' 'A' 'B' 'E' 'D' 'G' 'F']
# Value Counts:
#  loan_grade
# B    11551
# C    10948
# A     6764
# D     6237
# E     3158
# F     1030
# G      245
# Name: count, dtype: int64
#
# Column: loan_subgrade
# Unique values: ['C2' 'A4' 'C1' 'B3' 'B5' 'E1' 'E4' 'C3' 'E2' 'D4' 'D2' 'A3' 'B4' 'A1'
#  'G1' 'B1' 'A5' 'C4' 'B2' 'A2' 'F2' 'F1' 'D1' 'D5' 'D3' 'C5' 'F3' 'G3'
#  'E3' 'E5' 'F5' 'G2' 'F4' 'G4' 'G5']
# Value Counts:
#  loan_subgrade
# B3    2547
# B4    2519
# C1    2436
# C2    2371
# B5    2247
# C3    2220
# B2    2206
# C4    2084
# A5    2069
# B1    2032
# C5    1837
# D1    1576
# A4    1559
# D2    1373
# D3    1175
# D4    1141
# A3    1074
# A1    1067
# A2     995
# D5     972
# E1     803
# E2     755
# E3     652
# E4     519
# E5     429
# F1     312
# F2     254
# F3     195
# F4     147
# F5     122
# G2      72
# G1      71
# G3      46
# G5      31
# G4      25
# Name: count, dtype: int64
#
# Column: job_experience
# Unique values: ['<5 Years' '10+ years' '6-10 years' nan]
# Value Counts:
#  job_experience
# <5 Years      17290
# 10+ years     13146
# 6-10 years     7408
# Name: count, dtype: int64
#
# Column: home_ownership
# Unique values: ['MORTGAGE' 'RENT' 'OWN' 'OTHER' 'NONE']
# Value Counts:
#  home_ownership
# MORTGAGE    20008
# RENT        15938
# OWN          3979
# OTHER           6
# NONE            2
# Name: count, dtype: int64
#
# Column: income_verification_status
# Unique values: ['Not Verified' 'Verified' 'Source Verified']
# Value Counts:
#  income_verification_status
# Source Verified    14780
# Verified           13195
# Not Verified       11958
# Name: count, dtype: int64
#
# Column: loan_purpose
# Unique values: ['debt_consolidation' 'credit_card' 'other' 'home_improvement']
# Value Counts:
#  loan_purpose
# debt_consolidation    23473
# credit_card            9383
# other                  4693
# home_improvement       2384
# Name: count, dtype: int64
#
# Column: state_code
# Unique values: ['CA' 'VA' 'TX' 'NJ' 'OK' 'MA' 'KS' 'AL' 'NY' 'WA' 'NV' 'OH' 'IL' 'UT'
#  'CO' 'FL' 'MS' 'MI' 'MD' 'WI' 'OR' 'HI' 'MT' 'IN' 'KY' 'GA' 'PA' 'SC'
#  'LA' 'AZ' 'CT' 'NC' 'MO' 'MN' 'AR' 'NM' 'NH' 'TN' 'NE' 'AK' 'RI' 'WV'
#  'VT' 'DE' 'SD' 'ND' 'ME' 'WY' 'DC' 'ID']
# Value Counts:
#  state_code
# CA    5931
# NY    3409
# TX    3163
# FL    2714
# IL    1553
# NJ    1513
# PA    1391
# OH    1372
# GA    1351
# VA    1194
# NC    1063
# MI    1001
# MA     945
# MD     935
# AZ     917
# WA     908
# CO     869
# MN     708
# MO     650
# CT     587
# IN     577
# TN     557
# NV     544
# AL     525
# SC     494
# OR     479
# WI     474
# LA     458
# KY     414
# OK     365
# KS     346
# AR     315
# UT     280
# NM     214
# WV     213
# NH     212
# HI     209
# MS     158
# RI     156
# DE     123
# MT     113
# AK     100
# DC      99
# VT      88
# WY      82
# SD      65
# NE      58
# ND      20
# ME      20
# ID       1
# Name: count, dtype: int64
#
# Column: application_type
# Unique values: ['INDIVIDUAL' 'JOINT']
# Value Counts:
#  application_type
# INDIVIDUAL    39909
# JOINT            24
# Name: count, dtype: int64

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of numerical features using histograms or box plots to detect outliers and understand their spread, analyze the target variable distribution, calculate and visualize the correlation matrix of numerical features, and check for skewness in numerical features.

# %%
# Visualize distributions of numerical features using box plots to detect outliers
numerical_cols_to_plot = numerical_cols_train.drop(['ID', 'default']) # Exclude ID and target

n_cols = 4
n_rows = (len(numerical_cols_to_plot) + n_cols - 1) // n_cols

plt.figure(figsize=(15, n_rows * 5))

for i, col in enumerate(numerical_cols_to_plot):
    plt.subplot(n_rows, n_cols, i + 1)
    sns.boxplot(y=train_df[col])
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# Analyze the distribution of the target variable ('default') in the training dataset
plt.figure(figsize=(6, 4))
sns.countplot(x='default', data=train_df)
plt.title('Distribution of Target Variable (default)')
plt.xlabel('Default Status')
plt.ylabel('Count')
plt.show()

# Calculate and visualize the correlation matrix of numerical features in the training data
correlation_matrix = train_df[numerical_cols_train].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Features (Train Data)')
plt.show()

# Check for skewness in numerical features
skewness = train_df[numerical_cols_train].skew()
print("\nSkewness of numerical features in train data:")
print(skewness)
# Out:
# Skewness of numerical features in train data:
# ID                         0.017670
# loan_amnt                  0.686590
# interest_rate              0.426024
# annual_income             56.670843
# debt_to_income             5.005686
# delinq_2yrs                5.659050
# public_records            10.940287
# revolving_balance         24.717052
# total_acc                  0.892762
# interest_receive           2.835085
# last_week_pay              1.012250
# total_current_balance      4.365655
# total_revolving_limit    113.430661
# default                    1.233702
# dtype: float64

# %% [markdown]
# ## Data preprocessing
#
# ### Subtask:
# Handle missing values, encode categorical features, scale numerical features, and remove outliers. Save the scaler for later use.

# %% [markdown]
# **Reasoning**:
# Handle missing values using imputation and create a new category for missing categorical values, encode categorical features using one-hot encoding, scale numerical features using StandardScaler and save the scaler, and handle outliers using clipping.

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.8.1

# %% [markdown]
# **Reasoning**:
# The previous attempt failed due to a missing library. I need to correct the code to use available libraries and ensure the preprocessing steps (handling missing values, encoding, scaling, outlier handling) are correctly applied. I will use StandardScaler and OneHotEncoder from sklearn, and SimpleImputer for missing values. I will also use clipping for outlier handling as planned.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import joblib
import warnings
warnings.filterwarnings("ignore")

# === 1️⃣ Define feature groups ===
label_encoded_features = ['loan_term', 'loan_grade', 'loan_subgrade', 'job_experience', 'application_type']
onehot_encoded_features = ['home_ownership', 'income_verification_status', 'loan_purpose']
target_encoded_features = ['state_code']

# Identify numerical features (excluding ID and target variable)
numerical_features = train_df.select_dtypes(include=np.number).columns.tolist()
numerical_features.remove('ID')
numerical_features.remove('default')

# === 2️⃣ Remove rows with missing target values ===
train_df = train_df.dropna(subset=['default'])

# === 3️⃣ Split data ===
X_train = train_df.drop('default', axis=1)
y_train = train_df['default'].astype(int)
X_test = test_df.copy()

# === 4️⃣ Define transformers ===
numerical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

label_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

onehot_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

target_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('target', TargetEncoder(handle_unknown='value', handle_missing='value'))
])

# === 5️⃣ Combine all transformers ===
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('label', label_transformer, label_encoded_features),
        ('onehot', onehot_transformer, onehot_encoded_features),
        ('target', target_transformer, target_encoded_features)
    ],
    remainder='drop'
)

# === 6️⃣ Fit & transform ===
X_train_preprocessed = preprocessor.fit_transform(X_train, y_train)
X_test_preprocessed = preprocessor.transform(X_test)

# === 7️⃣ Get feature names ===
num_feature_names = numerical_features
label_feature_names = label_encoded_features
onehot_feature_names = preprocessor.named_transformers_['onehot'].named_steps['onehot'].get_feature_names_out(onehot_encoded_features)
target_feature_names = target_encoded_features
all_feature_names = list(num_feature_names) + list(label_feature_names) + list(onehot_feature_names) + list(target_feature_names)

# === 8️⃣ Convert to DataFrame ===
X_train_preprocessed_df = pd.DataFrame(X_train_preprocessed, columns=all_feature_names)
X_test_preprocessed_df = pd.DataFrame(X_test_preprocessed, columns=all_feature_names)

print(f"✅ Preprocessing completed!\nTrain shape: {X_train_preprocessed_df.shape}\nTest shape: {X_test_preprocessed_df.shape}")

# === 9️⃣ Save pipeline ===
joblib.dump(preprocessor, "preprocessor_pipeline.pkl")
print("🧠 Saved preprocessing pipeline as 'preprocessor_pipeline.pkl'")
# Out:
# ✅ Preprocessing completed!
# Train shape: (93174, 30)
# Test shape: (39933, 30)
# 🧠 Saved preprocessing pipeline as 'preprocessor_pipeline.pkl'

# %%
from imblearn.combine import SMOTEENN
from collections import Counter

# === 1️⃣ Check original distribution ===
print("📊 Original class distribution:", Counter(y_train))

# === 2️⃣ Apply SMOTEENN ===
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X_train_preprocessed_df, y_train)

# === 3️⃣ Check new distribution ===
print("✅ After SMOTEENN balancing:", Counter(y_resampled))

# === 4️⃣ Convert back to DataFrame (for easy inspection or saving) ===
X_resampled_df = pd.DataFrame(X_resampled, columns=X_train_preprocessed_df.columns)
y_resampled = pd.Series(y_resampled, name='default')

print(f"\n🔹 Resampled X shape: {X_resampled_df.shape}")
print(f"🔹 Resampled y shape: {y_resampled.shape}")
# Out:
# 📊 Original class distribution: Counter({0: 71045, 1: 22129})
# ✅ After SMOTEENN balancing: Counter({1: 60324, 0: 32348})
#
# 🔹 Resampled X shape: (92672, 30)
# 🔹 Resampled y shape: (92672,)

# %%
X_train.shape, X_test.shape
# Out:
# ((93174, 22), (39933, 22))

# %% [markdown]
# ## Model Building
#
# ### Subtask:
# Split train data into X_train, X_test, y_train, y_test. Train multiple classification models and evaluate using Accuracy, Precision, Recall, F1-score, and Confusion Matrix. Compare results and choose the best-performing model.

# %% [markdown]
# **Reasoning**:
# Split the preprocessed training data into training and validation sets, train different classification models, evaluate each model using specified metrics, and store the results in a DataFrame for comparison.

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 9.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
from sklearn.model_selection import train_test_split

X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_resampled, y_resampled,
    test_size=0.2,
    random_state=42,
    stratify=y_resampled  # ✅ Stratify after resampling
)

# Show the shapes and balance
print("✅ Data Shapes After Resampling and Split:")
print(f"X_train_split: {X_train_split.shape}")
print(f"X_val_split:   {X_val_split.shape}")
print(f"y_train_split: {y_train_split.shape}")
print(f"y_val_split:   {y_val_split.shape}")

print("\n🎯 Class Distribution After Resampling:")
print(y_resampled.value_counts())
# Out:
# ✅ Data Shapes After Resampling and Split:
# X_train_split: (74137, 30)
# X_val_split:   (18535, 30)
# y_train_split: (74137,)
# y_val_split:   (18535,)
#
# 🎯 Class Distribution After Resampling:
# default
# 1    60324
# 0    32348
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (
    RandomForestClassifier, GradientBoostingClassifier,
    ExtraTreesClassifier, AdaBoostClassifier
)
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pandas as pd
import time

# === 1️⃣ Split the balanced (resampled) data ===
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_resampled, y_resampled,
    test_size=0.2,
    random_state=42,
    stratify=y_resampled
)

print("✅ Data Shapes After Resampling and Split:")
print(f"X_train_split: {X_train_split.shape}")
print(f"X_val_split:   {X_val_split.shape}")
print(f"y_train_split: {y_train_split.shape}")
print(f"y_val_split:   {y_val_split.shape}")

print("\n🎯 Class Distribution After Resampling:")
print(y_resampled.value_counts())

# === 2️⃣ Initialize all models ===
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=200, random_state=42, n_jobs=-1),
    "XGBoost (GPU)": XGBClassifier(
        tree_method='hist',
        predictor='gpu_predictor',
        device='cuda',
        eval_metric='logloss',
        random_state=42
    ),
    "LightGBM (GPU)": LGBMClassifier(
        device='gpu',
        gpu_platform_id=0,
        gpu_device_id=0,
        random_state=42
    ),
    "CatBoost (GPU)": CatBoostClassifier(
        task_type='GPU',
        devices='0',
        verbose=0,
        random_state=42
    ),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=200, random_state=42, n_jobs=-1),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "KNN": KNeighborsClassifier(n_jobs=-1)
}

# === 3️⃣ Train and evaluate all models ===
results = []
for name, model in models.items():
    print(f"\n🚀 Training {name}...")
    start = time.time()
    model.fit(X_train_split, y_train_split)
    end = time.time()

    y_pred = model.predict(X_val_split)

    accuracy = accuracy_score(y_val_split, y_pred)
    precision = precision_score(y_val_split, y_pred)
    recall = recall_score(y_val_split, y_pred)
    f1 = f1_score(y_val_split, y_pred)
    cm = confusion_matrix(y_val_split, y_pred)

    results.append({
        "Model": name,
        "Accuracy": round(accuracy, 4),
        "Precision": round(precision, 4),
        "Recall": round(recall, 4),
        "F1-score": round(f1, 4),
        "Train Time (min)": round((end - start) / 60, 2),
        "Confusion Matrix": cm.tolist()
    })

    print(f"✅ {name} - Acc: {accuracy:.4f}, Prec: {precision:.4f}, Rec: {recall:.4f}, F1: {f1:.4f}")
    print(f"⏱️ Time: {(end - start)/60:.2f} min")

# === 4️⃣ Display results ===
results_df = pd.DataFrame(results)
print("\n📊 Model Comparison (Sorted by F1-score):")
results_df = results_df.sort_values(by="F1-score", ascending=False).reset_index(drop=True)
display(results_df)
# Out:
# ✅ Data Shapes After Resampling and Split:
# X_train_split: (74137, 30)
# X_val_split:   (18535, 30)
# y_train_split: (74137,)
# y_val_split:   (18535,)
#
# 🎯 Class Distribution After Resampling:
# default
# 1    60324
# 0    32348
# Name: count, dtype: int64
#
# 🚀 Training Logistic Regression...
# ✅ Logistic Regression - Acc: 0.7924, Prec: 0.8216, Rec: 0.8700, F1: 0.8451
# ⏱️ Time: 0.10 min
#
# 🚀 Training Random Forest...
# ✅ Random Forest - Acc: 0.9180, Prec: 0.9215, Rec: 0.9554, F1: 0.9381
# ⏱️ Time: 0.85 min
#
# 🚀 Training XGBoost (GPU)...
# ✅ XGBoost (GPU) - Acc: 0.9356, Prec: 0.9557, Rec: 0.9450, F1: 0.9503
# ⏱️ Time: 0.02 min
#
# 🚀 Training LightGBM (GPU)...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 48259, number of negative: 25878
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6886
# [LightGBM] [Info] Number of data points in the train set: 74137, number of used features: 29
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (1.41 MB) transferred to GPU in 0.002825 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650944 -> initscore=0.623189
# [LightGBM] [Info] Start training from score 0.623189
# ✅ LightGBM (GPU) - Acc: 0.9265, Prec: 0.9475, Rec: 0.9391, F1: 0.9433
# ⏱️ Time: 0.11 min
#
# 🚀 Training CatBoost (GPU)...
# ✅ CatBoost (GPU) - Acc: 0.9285, Prec: 0.9479, Rec: 0.9419, F1: 0.9449
# ⏱️ Time: 0.13 min
#
# 🚀 Training Gradient Boosting...
# ✅ Gradient Boosting - Acc: 0.8561, Prec: 0.8665, Rec: 0.9208, F1: 0.8928
# ⏱️ Time: 0.70 min
#
# 🚀 Training Extra Trees...
# ✅ Extra Trees - Acc: 0.9378, Prec: 0.9357, Rec: 0.9712, F1: 0.9531
# ⏱️ Time: 0.28 min
#
# 🚀 Training AdaBoost...
# ✅ AdaBoost - Acc: 0.7871, Prec: 0.8051, Rec: 0.8879, F1: 0.8445
# ⏱️ Time: 0.12 min
#
# 🚀 Training KNN...
# ✅ KNN - Acc: 0.9129, Prec: 0.8898, Rec: 0.9886, F1: 0.9366
# ⏱️ Time: 0.00 min
#
# 📊 Model Comparison (Sorted by F1-score):
#                  Model  Accuracy  Precision  Recall  F1-score  \
# 0          Extra Trees    0.9378     0.9357  0.9712    0.9531
# 1        XGBoost (GPU)    0.9356     0.9557  0.9450    0.9503
# 2       CatBoost (GPU)    0.9285     0.9479  0.9419    0.9449
# 3       LightGBM (GPU)    0.9265     0.9475  0.9391    0.9433
# 4        Random Forest    0.9180     0.9215  0.9554    0.9381
# 5                  KNN    0.9129     0.8898  0.9886    0.9366
# 6    Gradient Boosting    0.8561     0.8665  0.9208    0.8928
# 7  Logistic Regression    0.7924     0.8216  0.8700    0.8451
# 8             AdaBoost    0.7871     0.8051  0.8879    0.8445
#
#    Train Time (min)               Confusion Matrix
# 0              0.28    [[5665, 805], [348, 11717]]
# 1              0.02    [[5941, 529], [664, 11401]]
# 2              0.13    [[5846, 624], [701, 11364]]
# 3              0.11    [[5842, 628], [735, 11330]]
# 4              0.85    [[5488, 982], [538, 11527]]
# 5              0.00   [[4993, 1477], [138, 11927]]
# 6              0.70   [[4759, 1711], [956, 11109]]
# 7              0.10  [[4191, 2279], [1568, 10497]]
# 8              0.12  [[3876, 2594], [1352, 10713]]

# %%
import pandas as pd
import time
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier

# ======================================
# ⚙️ Step 1: Data Info
# ======================================
print(f"✅ X_train_split shape: {X_train_split.shape}")
print(f"✅ y_train_split shape: {y_train_split.shape}")
print(f"✅ X_val_split shape: {X_val_split.shape}")
print(f"✅ y_val_split shape: {y_val_split.shape}")

print(f"\n📊 Class Distribution in Train Set:")
print(y_train_split.value_counts().to_dict())

# ======================================
# 🏆 Step 2: Define Models (GPU optimized)
# ======================================
top_models = ['XGBoost', 'LightGBM', 'CatBoost', 'Extra Trees']
print(f"\n🏆 Models Selected: {top_models}")

models = {
    "XGBoost": XGBClassifier(
        device='cuda',
        tree_method='hist',
        predictor='gpu_predictor',
        eval_metric='logloss',
        random_state=42,
        use_label_encoder=False
    ),
    "LightGBM": LGBMClassifier(
        device_type='gpu',        # ✅ Correct param
        gpu_platform_id=0,
        gpu_device_id=0,
        random_state=42
    ),
    "CatBoost": CatBoostClassifier(
        task_type='GPU',
        devices='0',
        verbose=0,
        random_state=42
    ),
    "Extra Trees": ExtraTreesClassifier(
        n_jobs=-1,
        random_state=42
    )
}

# ======================================
# 🎯 Step 3: Simplified Parameter Grids
# ======================================
param_grids = {
    "XGBoost": {
        'n_estimators': [200, 400],
        'learning_rate': [0.03, 0.1],
        'max_depth': [4, 6],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
    },
    "LightGBM": {
        'n_estimators': [200, 400],
        'learning_rate': [0.03, 0.1],
        'num_leaves': [31, 63],
        'max_depth': [-1, 10],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
    },
    "CatBoost": {
        'depth': [6, 8],
        'learning_rate': [0.03, 0.1],
        'iterations': [300, 500],
        'l2_leaf_reg': [3, 5]
    },
    "Extra Trees": {
        'n_estimators': [100, 200],
        'max_depth': [None, 20],
        'min_samples_split': [2, 5],
        'min_samples_leaf': [1, 2],
        'max_features': ['sqrt', None]
    }
}

# ======================================
# 🚀 Step 4: RandomizedSearchCV
# ======================================
best_models = {}

for model_name in top_models:
    print(f"\n🔍 Now tuning: {model_name}")
    model = models[model_name]
    param_grid = param_grids[model_name]

    random_search = RandomizedSearchCV(
        estimator=model,
        param_distributions=param_grid,
        n_iter=3,         # faster test; increase to 10–20 for final
        scoring='f1',
        cv=2,             # 2-fold for speed (change to 3–5 for final)
        verbose=1,
        random_state=42,
        n_jobs=-1 if model_name == "Extra Trees" else 1
    )

    start_time = time.time()
    random_search.fit(X_train_split, y_train_split)
    duration = (time.time() - start_time) / 60

    best_models[model_name] = random_search.best_estimator_
    print(f"✅ Best Params for {model_name}: {random_search.best_params_}")
    print(f"🏁 Best F1 Score: {random_search.best_score_:.4f}")
    print(f"⏱️ Time Taken: {duration:.2f} minutes")

# ======================================
# 📊 Step 5: Evaluation on Validation Set
# ======================================
results = []

for name, tuned_model in best_models.items():
    print(f"\n📈 Evaluating {name}...")
    y_pred = tuned_model.predict(X_val_split)

    acc = accuracy_score(y_val_split, y_pred)
    prec = precision_score(y_val_split, y_pred)
    rec = recall_score(y_val_split, y_pred)
    f1 = f1_score(y_val_split, y_pred)
    cm = confusion_matrix(y_val_split, y_pred)

    results.append({
        "Model": name,
        "Accuracy": round(acc, 4),
        "Precision": round(prec, 4),
        "Recall": round(rec, 4),
        "F1-score": round(f1, 4),
        "Confusion Matrix": cm.tolist()
    })

results_df = pd.DataFrame(results).sort_values(by='F1-score', ascending=False)
print("\n📊 Final Tuned Model Comparison (sorted by F1-score):")
display(results_df)

best_model_name = results_df.iloc[0]['Model']
print(f"\n🏅 Best Model after Tuning: {best_model_name}")
# Out:
# ✅ X_train_split shape: (74137, 30)
# ✅ y_train_split shape: (74137,)
# ✅ X_val_split shape: (18535, 30)
# ✅ y_val_split shape: (18535,)
#
# 📊 Class Distribution in Train Set:
# {1: 48259, 0: 25878}
#
# 🏆 Models Selected: ['XGBoost', 'LightGBM', 'CatBoost', 'Extra Trees']
#
# 🔍 Now tuning: XGBoost
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# ✅ Best Params for XGBoost: {'subsample': 1.0, 'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
# 🏁 Best F1 Score: 0.9523
# ⏱️ Time Taken: 0.09 minutes
#
# 🔍 Now tuning: LightGBM
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 24129, number of negative: 12939
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6877
# [LightGBM] [Info] Number of data points in the train set: 37068, number of used features: 28
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (0.71 MB) transferred to GPU in 0.002941 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650939 -> initscore=0.623168
# [LightGBM] [Info] Start training from score 0.623168
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 24130, number of negative: 12939
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6869
# [LightGBM] [Info] Number of data points in the train set: 37069, number of used features: 27
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (0.71 MB) transferred to GPU in 0.001579 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650948 -> initscore=0.623210
# [LightGBM] [Info] Start training from score 0.623210
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 24129, number of negative: 12939
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6877
# [LightGBM] [Info] Number of data points in the train set: 37068, number of used features: 28
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (0.71 MB) transferred to GPU in 0.001570 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650939 -> initscore=0.623168
# [LightGBM] [Info] Start training from score 0.623168
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 24130, number of negative: 12939
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6869
# [LightGBM] [Info] Number of data points in the train set: 37069, number of used features: 27
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (0.71 MB) transferred to GPU in 0.003001 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650948 -> initscore=0.623210
# [LightGBM] [Info] Start training from score 0.623210
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 24129, number of negative: 12939
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6877
# [LightGBM] [Info] Number of data points in the train set: 37068, number of used features: 28
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (0.71 MB) transferred to GPU in 0.001491 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650939 -> initscore=0.623168
# [LightGBM] [Info] Start training from score 0.623168
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 24130, number of negative: 12939
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6869
# [LightGBM] [Info] Number of data points in the train set: 37069, number of used features: 27
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (0.71 MB) transferred to GPU in 0.001566 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650948 -> initscore=0.623210
# [LightGBM] [Info] Start training from score 0.623210
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 48259, number of negative: 25878
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6886
# [LightGBM] [Info] Number of data points in the train set: 74137, number of used features: 29
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (1.41 MB) transferred to GPU in 0.002848 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650944 -> initscore=0.623189
# [LightGBM] [Info] Start training from score 0.623189
# ✅ Best Params for LightGBM: {'subsample': 0.8, 'num_leaves': 31, 'n_estimators': 400, 'max_depth': -1, 'learning_rate': 0.1, 'colsample_bytree': 1.0}
# 🏁 Best F1 Score: 0.9539
# ⏱️ Time Taken: 0.41 minutes
#
# 🔍 Now tuning: CatBoost
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# ✅ Best Params for CatBoost: {'learning_rate': 0.1, 'l2_leaf_reg': 3, 'iterations': 500, 'depth': 6}
# 🏁 Best F1 Score: 0.9502
# ⏱️ Time Taken: 0.80 minutes
#
# 🔍 Now tuning: Extra Trees
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# ✅ Best Params for Extra Trees: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None}
# 🏁 Best F1 Score: 0.9292
# ⏱️ Time Taken: 2.64 minutes
#
# 📈 Evaluating XGBoost...
#
# 📈 Evaluating LightGBM...
#
# 📈 Evaluating CatBoost...
#
# 📈 Evaluating Extra Trees...
#
# 📊 Final Tuned Model Comparison (sorted by F1-score):
#          Model  Accuracy  Precision  Recall  F1-score  \
# 1     LightGBM    0.9417     0.9640  0.9458    0.9548
# 0      XGBoost    0.9409     0.9605  0.9481    0.9543
# 2     CatBoost    0.9338     0.9549  0.9428    0.9488
# 3  Extra Trees    0.9318     0.9321  0.9655    0.9485
#
#               Confusion Matrix
# 1  [[6044, 426], [654, 11411]]
# 0  [[6000, 470], [626, 11439]]
# 2  [[5933, 537], [690, 11375]]
# 3  [[5621, 849], [416, 11649]]
# 🏅 Best Model after Tuning: LightGBM

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import time

# ======================================
# ⚙️ Step 6: Final Training for LightGBM
# ======================================

# 🏆 Best params from tuning
best_xgb_params = {
    'learning_rate': 0.1,
    'n_estimators': 400,
    'max_depth': 6,
    'subsample': 1.0,
    'colsample_bytree': 0.8,
    'tree_method': 'hist',         # enables fast GPU-compatible histogram algo
    'predictor': 'gpu_predictor',  # GPU inference
    'device': 'cuda',              # use CUDA GPU
    'random_state': 42,
    'eval_metric': 'logloss'
}


# ⚙️ Initialize final model
final_lgbm = LGBMClassifier(**best_lgbm_params)

# 🚀 Train on full preprocessed training data
print("\n🚀 Training final LightGBM model on full training data...")
start = time.time()
final_lgbm.fit(X_train_split, y_train_split)
end = time.time()
print(f"✅ Training complete! Time taken: {(end - start)/60:.2f} minutes\n")

# 🎯 Evaluate on validation data
y_pred_final = final_lgbm.predict(X_val_split)

# 📊 Compute metrics
accuracy = accuracy_score(y_val_split, y_pred_final)
precision = precision_score(y_val_split, y_pred_final)
recall = recall_score(y_val_split, y_pred_final)
f1 = f1_score(y_val_split, y_pred_final)
cm = confusion_matrix(y_val_split, y_pred_final)

# 🧾 Print final performance
print("📈 Final LightGBM Model Evaluation:")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-score:  {f1:.4f}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# 🚀 Training final LightGBM model on full training data...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 48259, number of negative: 25878
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6886
# [LightGBM] [Info] Number of data points in the train set: 74137, number of used features: 29
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 17 dense feature groups (1.41 MB) transferred to GPU in 0.003007 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650944 -> initscore=0.623189
# [LightGBM] [Info] Start training from score 0.623189
# ✅ Training complete! Time taken: 0.07 minutes
#
# 📈 Final LightGBM Model Evaluation:
# Accuracy:  0.9417
# Precision: 0.9640
# Recall:    0.9458
# F1-score:  0.9548
# Confusion Matrix:
# [[ 6044   426]
#  [  654 11411]]

# %%
print("\n🧠 Generating predictions on test data...")
y_test_pred = final_lgbm.predict(X_test_preprocessed_df)  # ✅ Correct variable

# ======================================
# 📁 Step 6: Create Submission File
# ======================================
submission = pd.DataFrame({
    'ID': test_df['ID'],
    'default': y_test_pred.astype(int)
})

# ✅ Validation checks
expected_rows = 39933
expected_columns = ['ID', 'default']

print("\n🔍 Validating submission format...")

if submission.shape[0] != expected_rows:
    raise ValueError(f"❌ Expected {expected_rows} rows, but got {submission.shape[0]}.")

if list(submission.columns) != expected_columns:
    raise ValueError(f"❌ Expected columns {expected_columns}, but got {list(submission.columns)}.")

if submission.isnull().any().any():
    raise ValueError("❌ Submission file contains missing values!")

# ✅ Save submission
submission.to_csv("submission.csv", index=False)
print("\n✅ Submission file saved successfully as 'submission.csv'")
print(f"📊 Shape: {submission.shape}")
print(f"📈 Default Value Distribution:\n{submission['default'].value_counts()}")
# Out:
# 🧠 Generating predictions on test data...
#
# 🔍 Validating submission format...
#
# ✅ Submission file saved successfully as 'submission.csv'
# 📊 Shape: (39933, 2)
# 📈 Default Value Distribution:
# default
# 0    28457
# 1    11476
# Name: count, dtype: int64

# %%
submission_df = pd.read_csv("/content/submission.csv")
submission_df.shape
# Out:
# (39933, 2)
